# %% [markdown]
# 1. Create a simple page with some div tags and show different ways to add CSS as well as what happens when you target the same elements with inline, internal, and external CSS. Also, utilize comments in the project where required
#     - <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#         /* Here this style is not applied because first priority goes to Inline CSS */
#         #firstDiv{
#             background-color: brown;
#             color: white;
#         }
#         /* Style using internal CSS */
#         #secondDiv{
#             background-color: aqua;
#             height: 30px;
#             text-align: center;
#             border: 1px solid red;
#         }
#         #thirdDIV{
#             background-color: beige;
#             color: black;
#         }
#     </style>
#     <!-- Style using external CSS -->
#     <link rel="stylesheet" href="style.css">
# </head>
# <body>
#     <!-- Style using inline CSS -->
#     <div id="firstDiv" style="background-color: black; color: white;"> I am first div</div>
#
#     <div id="secondDiv">I am second div</div>
#
#     <div id="thirdDiv">I am third div</div>
# </body>
# </html>

# %% [markdown]
# 2. Build an HTML page with multiple paragraphs, each assigned a unique class name. Write CSS rules usingclass selectors to apply distinct styling to each paragraph. Follow the BEM naming convention and explain how you've named the classes
#       -
#       <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#     <style>
#             *{
#         margin: 0;
#         padding: 0;
#           }
#       .para__one{
#       background-color: aqua;
#       color: blue;
#       height: 150px;
#       width: 150px;
#       border: 1px solid black;
#       }
#       .para__two{
#       background-color: blueviolet;
#       color: white;
#       height: 40px;
#       width: 300px;
#       border-radius: 10px;
#       border: 1px solid red;
#       }
#       .para__three{
#       margin-top: 10px;
#       height: 50px;
#       width: 300px;
#       text-align: center;
#       border: 2px solid ;
#       }
#       .para__three--highleted{
#           background-color: #f2f2f2;
#           margin-left: 70px;
#       }
#     </style>
# </head>
# <body>
#     <div class="para">
#     <div class="para__one">Lorem ipsum dolor sit amet consectetur adipisicing elit. Ipsa, asperiores.</div>
#     <div class="para__two">Lorem ipsum dolor, sit amet consectetur adipisicing elit. Facere, quam?</div>
#     <div class="para__three para__three--highleted">Lorem ipsum dolor sit amet.</div>
# </div>
# </body>
# </html>
#
# <!-- In this example, the para class is the Block, and the para__one, para__two, and para__three classes are Elements.
#  The para__three--highlighted class is a Modifier that changes the appearance of the para. -->

# %% [markdown]
# 3. Develop an HTML form with various input elements. Use CSS to style the form, including setting background colors for input fields. Create a custom color palette for the form elements, and demonstrate how to apply opacity to one of the form sections.
#       -
#       <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
#      <style>
#         *{
#                 background-color:gray;
#             }
#             .form{
#                 height: 200px;
#                 width: 300px;
#                 margin-left: 45%;
#                 margin-top: 10%;
#
#             }
#             .form__elements{
#             background-color: aqua;
#             padding: 10px;
#
#
#             }
#             #name{
#                 display: block;
#                 background-color: whitesmoke;
#             }
#             #password{
#             display: block;
#             background-color: whitesmoke;
#
#             }
#             #address{
#                 display: block;
#                 background-color: whitesmoke;
#             }
#             #submit{
#                 margin-top: 4px;
#                 margin-left: 45px;
#                 height: 30px;
#                 width: 70px;
#                 border: 1px solid whitesmoke;
#                 border-radius: 10px;
#                 background-color: rgb(63, 63, 96,0.8);
#                 color: white;
#             }
#
#      </style>
# </head>
# <body>
#     <form class="form">
#
#         <div class="form__elements">Name
#             <input type="text" id="name"  placeholder="name">
#         </div>
#         <div class="form__elements">Password
#             <input type="password" id="password" placeholder="password">
#         </div>
#         <div class="form__elements">Adress
#             <textarea name="address" id="address">Adress</textarea>
#         </div>
#         <div class="form__elements">
#             <input type="submit" id="submit" >
#         </div>
#     </form>
# </body>
# </html>
